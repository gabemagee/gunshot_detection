# %%
# File Directory 
import glob
import os
from os.path import isdir, join
from pathlib import Path

# Math
import numpy as np
from scipy.fftpack import fft
from scipy import signal
import librosa

# Dimension Reduction
from sklearn.decomposition import PCA

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import IPython.display as ipd
import librosa.display
import plotly.offline as py
import plotly.graph_objs as go
import plotly.tools as tls

# Data Pre-processing
import pandas as pd
from sklearn.model_selection import KFold
import soundfile

# Deep Learning
import tensorflow as tf
import tensorflow.keras as keras
from tensorflow.keras.layers import Dense, Dropout, Flatten
from tensorflow.keras import Input, layers
from tensorflow.keras import backend as K

# Configuration
py.init_notebook_mode(connected=True)

# %matplotlib inline
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
samples=[]
sample_rates=[]
labels = []
sample_slice_iteration = 0
gunshot_aggregator = {}
glassbreak_aggregator = {}

gunshot_sound_dir = "/Users/laurenogden/school/iupui/gunshot/data/gunshot/"

for file in os.listdir(gunshot_sound_dir):
    if file.endswith(".wav"):
        try:
            sample, sample_rate = librosa.load(gunshot_sound_dir + file)
            for i in range(0, sample.size - 44100, 44100):
                sample_slice = sample[i : i + 44100]
                label = 2
                gunshot_aggregator[sample_slice_iteration] = np.max(abs(sample_slice))
                sample_slice_iteration += 1
                if np.max(abs(sample_slice)) < 0.25:
                    label = 0

                samples.append(sample_slice)
                sample_rates.append(sample_rate)
                labels.append(label)
        except:
            sample, sample_rate = soundfile.read(gunshot_sound_dir + file)
            #print("Gunshot sound unrecognized by Librosa:", sample)
            pass
        
glassbreak_sound_dir = "/Users/laurenogden/school/iupui/gunshot/data/glassbreak/"

print("...Switching to glassbreak sounds...")

for file in os.listdir(glassbreak_sound_dir):
    if file.endswith(".wav"):
        try:
            sample, sample_rate = librosa.load(glassbreak_sound_dir + file)
            for i in range(0, sample.size - 44100, 44100):
                sample_slice = sample[i : i + 44100]
                label = 1
                glassbreak_aggregator[sample_slice_iteration] = np.max(abs(sample_slice))
                sample_slice_iteration += 1
                if np.max(abs(sample_slice)) < 0.5:
                    label = 0

                samples.append(sample_slice)
                sample_rates.append(sample_rate)
                labels.append(label)
        except:
            sample, sample_rate = soundfile.read(glassbreak_sound_dir + file)
            print("Glassbreak sound unrecognized by Librosa:", sample)
            pass
# Out:
# ...Switching to glassbreak sounds...

# %%
#read in the csv file of descriptors for all other urban sounds
sound_types = pd.read_csv("/Users/laurenogden/school/iupui/gunshot/data/train/train.csv")
print(sound_types.loc[0,'Class'])



urban_aggregator = {}
j=0
#read in all of the wav files similar to above
urban_sound_dir = "/Users/laurenogden/school/iupui/gunshot/data/train/Train/"
print(os.listdir(urban_sound_dir))

for file in os.listdir(urban_sound_dir):
    if file.endswith(".wav"):
        try:
            sample, sample_rate = librosa.load(urban_sound_dir + file)
            print("librosa read the file ok #" + str(j))
            for i in range(0, sample.size - 44100, 44100):
                sample_slice = sample[i : i + 44100]
                if(sound_types.loc[j, 'Class'] == "gun_shot"):
                    label = 2
                else:
                    label = 0
                urban_aggregator[sample_slice_iteration] = np.max(abs(sample_slice))
                sample_slice_iteration += 1
                if np.max(abs(sample_slice)) < 0.25:
                    label = 0

                samples.append(sample_slice)
                sample_rates.append(sample_rate)
                labels.append(label)
            j +=1
        except:
            sample, sample_rate = soundfile.read(urban_sound_dir + file)
            print("Urban sound unrecognized by Librosa:", sample)
            pass
# Out:
# siren
av', '1327.wav', '8465.wav', '7756.wav', '5141.wav', '8471.wav', '7742.wav', '8317.wav', '2174.wav', '4263.wav', '2612.wav', '6474.wav', '17.wav', '8459.wav', '857.wav', '6460.wav', '843.wav', '4277.wav', '3518.wav', '5169.wav', '2160.wav', '4511.wav', '7018.wav', '1469.wav', '7187.wav', '5790.wav', '5948.wav', '704.wav', '7839.wav', '710.wav', '3493.wav', '2955.wav', '5784.wav', '738.wav', '2969.wav', '5960.wav', '3322.wav', '8277.wav', '7144.wav', '8511.wav', '7622.wav', '5035.wav', '3444.wav', '2982.wav', '5021.wav', '2996.wav', '7636.wav', '6528.wav', '1521.wav', '8263.wav', '7150.wav', '4459.wav', '3336.wav', '2028.wav', '6266.wav', '7178.wav', '2000.wav', '2766.wav', '3478.wav', '4317.wav', '923.wav', '6500.wav', '8539.wav', '937.wav', '4303.wav', '6272.wav', '6925.wav', '1092.wav', '506.wav', '3685.wav', '5592.wav', '4854.wav', '260.wav', '7385.wav', '1938.wav', '4698.wav', '5586.wav', '4840.wav', '3691.wav', '6931.wav', '512.wav', '3861.wav', '1910.wav', '248.wav', '1904.wav', '4129.wav', '3646.wav', '2558.wav', '5237.wav', '1051.wav', '8713.wav', '7346.wav', '8075.wav', '1737.wav', '3120.wav', '5545.wav', '4883.wav', '7352.wav', '8061.wav', '1045.wav', '8707.wav', '3652.wav', '5223.wav ...
# librosa read the file ok #0
# librosa read the file ok #1
# librosa read the file ok #2
# librosa read the file ok #3
# librosa read the file ok #4
# librosa read the file ok #5
# librosa read the file ok #6
# librosa read the file ok #7
# librosa read the file ok #8
# librosa read the file ok #9
# librosa read the file ok #10
# librosa read the file ok #11
# librosa read the file ok #12
# librosa read the file ok #13
# librosa read the file ok #14
# librosa read the file ok #15
# librosa read the file ok #16
# librosa read the file ok #17
# librosa read the file ok #18
# librosa read the file ok #19
# librosa read the file ok #20
# librosa read the file ok #21
# librosa read the file ok #22
# librosa read the file ok #23
# librosa read the file ok #24
# librosa read the file ok #25
# librosa read the file ok #26
# librosa read the file ok #27
# librosa read the file ok #28
# librosa read the file ok #29
# librosa read the file ok #30
# librosa read the file ok #31
# librosa read the file ok #32
# librosa read the file ok #33
# librosa read the file ok #34
# librosa read the file ok #35
# librosa read the file ok #36
# librosa read the file ok #37
# librosa read the file ok #38
# librosa read the file ok #39
# librosa read the file ok #40
# librosa read the file ok #41
# librosa read the file ok #42
# librosa read the file ok #43
# librosa read the file ok #44
# librosa read the file ok #45
# librosa read the file ok #46
# librosa read the file ok #47
# librosa read the file ok #48
# librosa read the file ok #49
# librosa read the file ok #50
# librosa read the file ok #51
# librosa read the file ok #52
# librosa read the file ok #53
# librosa read the file ok #54
# librosa read the file ok #55
# librosa read the file ok #56
# librosa read the file ok #57
# librosa read the file ok #58
# librosa read the file ok #59
# librosa read the file ok #60
# librosa read the file ok #61
# librosa read the file ok #62
# librosa read the file ok #63
# librosa read the file ok #64
# librosa read the file ok #65
# librosa read the file ok #66
# librosa read the file ok #67
# librosa read the file ok #68
# librosa read the file ok #69
# librosa read the file ok #70
# librosa read the file ok #71
# librosa read the file ok #72
# librosa read the file ok #73
# librosa read the file ok #74
# librosa read the file ok #75
# librosa read the file ok #76
# librosa read the file ok #77
# librosa read the file ok #78
# librosa read the file ok #79
# librosa read the file ok #80
# librosa read the file ok #81
# librosa read the file ok #82
# librosa read the file ok #83
# librosa read the file ok #84
# librosa read the file ok #85
# librosa read the file ok #86
# librosa read the file ok #87
# librosa read the file ok #88
# librosa read the file ok #89
# librosa read the file ok #90
# librosa read the file ok #91
# librosa read the file ok #92
# librosa read the file ok #93
# librosa read the file ok #94
# librosa read the file ok #95
# librosa read the file ok #96
# librosa read the file ok #97
# librosa read the file ok #98
# librosa read the file ok #99
# librosa read the file ok #100
# librosa read the file ok #101
# librosa read the file ok #102
# librosa read the file ok #103
# librosa read the file ok #104
# librosa read the file ok #105
# librosa read the file ok #106
# librosa read the file ok #107
# librosa read the file ok #108
# librosa read the file ok #109
# librosa read the file ok #110
# librosa read the file ok #111
# librosa read the file ok #112
# librosa read the file ok #113
# librosa read the file ok #114
# librosa read the file ok #115
# librosa read the file ok #116
# librosa read the file ok #117
# librosa read the file ok #118
# librosa read the file ok #119
# librosa read the file ok #120
# librosa read the file ok #121
# librosa read the file ok #122
# librosa read the file ok #123
# librosa read the file ok #124
# librosa read the file ok #125
# librosa read the file ok #126
# librosa read the file ok #127
# librosa read the file ok #128
# librosa read the file ok #129
# librosa read the file ok #130
# librosa read the file ok #131
# librosa read the file ok #132
# librosa read the file ok #133
# librosa read the file ok #134
# librosa read the file ok #135
# librosa read the file ok #136
# librosa read the file ok #137
# librosa read the file ok #138
# librosa read the file ok #139
# librosa read the file ok #140
# librosa read the file ok #141
# librosa read the file ok #142
# librosa read the file ok #143
# librosa read the file ok #144
# librosa read the file ok #145
# librosa read the file ok #146
# librosa read the file ok #147
# librosa read the file ok #148
# librosa read the file ok #149
# librosa read the file ok #150
# librosa read the file ok #151
# librosa read the file ok #152
# librosa read the file ok #153
# librosa read the file ok #154
# librosa read the file ok #155
# librosa read the file ok #156
# librosa read the file ok #157
# librosa read the file ok #158
# librosa read the file ok #159
# librosa read the file ok #160
# librosa read the file ok #161
# librosa read the file ok #162
# librosa read the file ok #163
# librosa read the file ok #164
# librosa read the file ok #165
# librosa read the file ok #166
# librosa read the file ok #167
# librosa read the file ok #168
# librosa read the file ok #169
# librosa read the file ok #170
# librosa read the file ok #171
# librosa read the file ok #172
# librosa read the file ok #173
# librosa read the file ok #174
# librosa read the file ok #175
# librosa read the file ok #176
# librosa read the file ok #177
# librosa read the file ok #178
# librosa read the file ok #179
# librosa read the file ok #180
# librosa read the file ok #181
# librosa read the file ok #182
# librosa read the file ok #183
# librosa read the file ok #184
# librosa read the file ok #185
# librosa read the file ok #186
# librosa read the file ok #187
# librosa read the file ok #188
# librosa read the file ok #189
# librosa read the file ok #190
# librosa read the file ok #191
# librosa read the file ok #192
# librosa read the file ok #193
# librosa read the file ok #194
# librosa read the file ok #195
# librosa read the file ok #196
# librosa read the file ok #197
# librosa read the file ok #198
# librosa read the file ok #199
# librosa read the file ok #200
# librosa read the file ok #201
# librosa read the file ok #202
# librosa read the file ok #203
# librosa read the file ok #204
# librosa read the file ok #205
# librosa read the file ok #206
# librosa read the file ok #207
# librosa read the file ok #208
# librosa read the file ok #209
# librosa read the file ok #210
# librosa read the file ok #211
# librosa read the file ok #212
# librosa read the file ok #213
# librosa read the file ok #214
# librosa read the file ok #215
# librosa read the file ok #216
# librosa read the file ok #217
# librosa read the file ok #218
# librosa read the file ok #219
# librosa read the file ok #220
# librosa read the file ok #221
# librosa read the file ok #222
# librosa read the file ok #223
# librosa read the file ok #224
# librosa read the file ok #225
# librosa read the file ok #226
# librosa read the file ok #227
# librosa read the file ok #228
# librosa read the file ok #229
# librosa read the file ok #230
# librosa read the file ok #231
# librosa read the file ok #232
# librosa read the file ok #233
# librosa read the file ok #234
# librosa read the file ok #235
# librosa read the file ok #236
# librosa read the file ok #237
# librosa read the file ok #238
# librosa read the file ok #239
# librosa read the file ok #240
# librosa read the file ok #241
# librosa read the file ok #242
# librosa read the file ok #243
# librosa read the file ok #244
# librosa read the file ok #245
# librosa read the file ok #246
# librosa read the file ok #247
# librosa read the file ok #248
# librosa read the file ok #249
# librosa read the file ok #250
# librosa read the file ok #251
# librosa read the file ok #252
# librosa read the file ok #253
# librosa read the file ok #254
# librosa read the file ok #255
# librosa read the file ok #256
# librosa read the file ok #257
# librosa read the file ok #258
# librosa read the file ok #259
# librosa read the file ok #260
# librosa read the file ok #261
# librosa read the file ok #262
# librosa read the file ok #263
# librosa read the file ok #264
# librosa read the file ok #265
# librosa read the file ok #266
# librosa read the file ok #267
# librosa read the file ok #268
# librosa read the file ok #269
# librosa read the file ok #270
# librosa read the file ok #271
# librosa read the file ok #272
# librosa read the file ok #273
# librosa read the file ok #274
# librosa read the file ok #275
# librosa read the file ok #276
# librosa read the file ok #277
# librosa read the file ok #278
# librosa read the file ok #279
# librosa read the file ok #280
# librosa read the file ok #281
# librosa read the file ok #282
# librosa read the file ok #283
# librosa read the file ok #284
# librosa read the file ok #285
# librosa read the file ok #286
# librosa read the file ok #287
# librosa read the file ok #288
# librosa read the file ok #289
# librosa read the file ok #290
# librosa read the file ok #291
# librosa read the file ok #292
# librosa read the file ok #293
# librosa read the file ok #294
# librosa read the file ok #295
# librosa read the file ok #296
# librosa read the file ok #297
# librosa read the file ok #298
# librosa read the file ok #299
# librosa read the file ok #300
# librosa read the file ok #301
# librosa read the file ok #302
# librosa read the file ok #303
# librosa read the file ok #304
# librosa read the file ok #305
# librosa read the file ok #306
# librosa read the file ok #307
# librosa read the file ok #308
# librosa read the file ok #309
# librosa read the file ok #310
# librosa read the file ok #311
# librosa read the file ok #312
# librosa read the file ok #313
# librosa read the file ok #314
# librosa read the file ok #315
# librosa read the file ok #316
# librosa read the file ok #317
# librosa read the file ok #318
# librosa read the file ok #319
# librosa read the file ok #320
# librosa read the file ok #321
# librosa read the file ok #322
# librosa read the file ok #323
# librosa read the file ok #324
# librosa read the file ok #325
# librosa read the file ok #326
# librosa read the file ok #327
# librosa read the file ok #328
# librosa read the file ok #329
# librosa read the file ok #330
# librosa read the file ok #331
# librosa read the file ok #332
# librosa read the file ok #333
# librosa read the file ok #334
# librosa read the file ok #335
# librosa read the file ok #336
# librosa read the file ok #337
# librosa read the file ok #338
# librosa read the file ok #339
# librosa read the file ok #340
# librosa read the file ok #341
# librosa read the file ok #342
# librosa read the file ok #343
# librosa read the file ok #344
# librosa read the file ok #345
# librosa read the file ok #346
# librosa read the file ok #347
# librosa read the file ok #348
# librosa read the file ok #349
# librosa read the file ok #350
# librosa read the file ok #351
# librosa read the file ok #352
# librosa read the file ok #353
# librosa read the file ok #354
# librosa read the file ok #355
# librosa read the file ok #356
# librosa read the file ok #357
# librosa read the file ok #358
# librosa read the file ok #359
# librosa read the file ok #360
# librosa read the file ok #361
# librosa read the file ok #362
# librosa read the file ok #363
# librosa read the file ok #364
# librosa read the file ok #365
# librosa read the file ok #366
# librosa read the file ok #367
# librosa read the file ok #368
# librosa read the file ok #369
# librosa read the file ok #370
# librosa read the file ok #371
# librosa read the file ok #372
# librosa read the file ok #373
# librosa read the file ok #374
# librosa read the file ok #375
# librosa read the file ok #376
# librosa read the file ok #377
# librosa read the file ok #378
# librosa read the file ok #379
# librosa read the file ok #380
# librosa read the file ok #381
# librosa read the file ok #382
# librosa read the file ok #383
# librosa read the file ok #384
# librosa read the file ok #385
# librosa read the file ok #386
# librosa read the file ok #387
# librosa read the file ok #388
# librosa read the file ok #389
# librosa read the file ok #390
# librosa read the file ok #391
# librosa read the file ok #392
# librosa read the file ok #393
# librosa read the file ok #394
# librosa read the file ok #395
# librosa read the file ok #396
# librosa read the file ok #397
# librosa read the file ok #398
# librosa read the file ok #399
# librosa read the file ok #400
# librosa read the file ok #401
# librosa read the file ok #402
# librosa read the file ok #403
# librosa read the file ok #404
# librosa read the file ok #405
# librosa read the file ok #406
# librosa read the file ok #407
# librosa read the file ok #408
# librosa read the file ok #409
# librosa read the file ok #410
# librosa read the file ok #411
# librosa read the file ok #412
# librosa read the file ok #413
# librosa read the file ok #414
# librosa read the file ok #415
# librosa read the file ok #416
# librosa read the file ok #417
# librosa read the file ok #418
# librosa read the file ok #419
# librosa read the file ok #420
# librosa read the file ok #421
# librosa read the file ok #422
# librosa read the file ok #423
# librosa read the file ok #424
# librosa read the file ok #425
# librosa read the file ok #426
# librosa read the file ok #427
# librosa read the file ok #428
# librosa read the file ok #429
# librosa read the file ok #430
# librosa read the file ok #431
# librosa read the file ok #432
# librosa read the file ok #433
# librosa read the file ok #434
# librosa read the file ok #435
# librosa read the file ok #436
# librosa read the file ok #437
# librosa read the file ok #438
# librosa read the file ok #439
# librosa read the file ok #440
# librosa read the file ok #441
# librosa read the file ok #442
# librosa read the file ok #443
# librosa read the file ok #444
# librosa read the file ok #445
# librosa read the file ok #446
# librosa read the file ok #447
# librosa read the file ok #448
# librosa read the file ok #449
# librosa read the file ok #450
# librosa read the file ok #451
# librosa read the file ok #452
# librosa read the file ok #453
# librosa read the file ok #454
# librosa read the file ok #455
# librosa read the file ok #456
# librosa read the file ok #457
# librosa read the file ok #458
# librosa read the file ok #459
# librosa read the file ok #460
# librosa read the file ok #461
# librosa read the file ok #462
# librosa read the file ok #463
# librosa read the file ok #464
# librosa read the file ok #465
# librosa read the file ok #466
# librosa read the file ok #467
# librosa read the file ok #468
# librosa read the file ok #469
# librosa read the file ok #470
# librosa read the file ok #471
# librosa read the file ok #472
# librosa read the file ok #473
# librosa read the file ok #474
# librosa read the file ok #475
# librosa read the file ok #476
# librosa read the file ok #477
# librosa read the file ok #478
# librosa read the file ok #479
# librosa read the file ok #480
# librosa read the file ok #481
# librosa read the file ok #482
# librosa read the file ok #483
# librosa read the file ok #484
# librosa read the file ok #485
# librosa read the file ok #486
# librosa read the file ok #487
# librosa read the file ok #488
# librosa read the file ok #489
# librosa read the file ok #490
# librosa read the file ok #491
# librosa read the file ok #492
# librosa read the file ok #493
# librosa read the file ok #494
# librosa read the file ok #495
# librosa read the file ok #496
# librosa read the file ok #497
# librosa read the file ok #498
# librosa read the file ok #499
# librosa read the file ok #500
# librosa read the file ok #501
# librosa read the file ok #502
# librosa read the file ok #503
# librosa read the file ok #504
# librosa read the file ok #505
# librosa read the file ok #506
# librosa read the file ok #507
# librosa read the file ok #508
# librosa read the file ok #509
# librosa read the file ok #510
# librosa read the file ok #511
# librosa read the file ok #512
# librosa read the file ok #513
# librosa read the file ok #514
# librosa read the file ok #515
# librosa read the file ok #516
# librosa read the file ok #517
# librosa read the file ok #518
# librosa read the file ok #519
# librosa read the file ok #520
# librosa read the file ok #521
# librosa read the file ok #522
# librosa read the file ok #523
# librosa read the file ok #524
# librosa read the file ok #525
# librosa read the file ok #526
# librosa read the file ok #527
# librosa read the file ok #528
# librosa read the file ok #529
# librosa read the file ok #530
# librosa read the file ok #531
# librosa read the file ok #532
# librosa read the file ok #533
# librosa read the file ok #534
# librosa read the file ok #535
# librosa read the file ok #536
# librosa read the file ok #537
# librosa read the file ok #538
# librosa read the file ok #539
# librosa read the file ok #540
# librosa read the file ok #541
# librosa read the file ok #542
# librosa read the file ok #543
# librosa read the file ok #544
# librosa read the file ok #545
# librosa read the file ok #546
# librosa read the file ok #547
# librosa read the file ok #548
# librosa read the file ok #549
# librosa read the file ok #550
# librosa read the file ok #551
# librosa read the file ok #552
# librosa read the file ok #553
# librosa read the file ok #554
# librosa read the file ok #555
# librosa read the file ok #556
# librosa read the file ok #557
# librosa read the file ok #558
# librosa read the file ok #559
# librosa read the file ok #560
# librosa read the file ok #561
# librosa read the file ok #562
# librosa read the file ok #563
# librosa read the file ok #564
# librosa read the file ok #565
# librosa read the file ok #566
# librosa read the file ok #567
# librosa read the file ok #568
# librosa read the file ok #569
# librosa read the file ok #570
# librosa read the file ok #571
# librosa read the file ok #572
# librosa read the file ok #573
# librosa read the file ok #574
# librosa read the file ok #575
# librosa read the file ok #576
# librosa read the file ok #577
# librosa read the file ok #578
# librosa read the file ok #579
# librosa read the file ok #580
# librosa read the file ok #581
# librosa read the file ok #582
# librosa read the file ok #583
# librosa read the file ok #584
# librosa read the file ok #585
# librosa read the file ok #586
# librosa read the file ok #587
# librosa read the file ok #588
# librosa read the file ok #589
# librosa read the file ok #590
# librosa read the file ok #591
# librosa read the file ok #592
# librosa read the file ok #593
# librosa read the file ok #594
# librosa read the file ok #595
# librosa read the file ok #596
# librosa read the file ok #597
# librosa read the file ok #598
# librosa read the file ok #599
# librosa read the file ok #600
# librosa read the file ok #601
# librosa read the file ok #602
# librosa read the file ok #603
# librosa read the file ok #604
# librosa read the file ok #605
# librosa read the file ok #606
# librosa read the file ok #607
# librosa read the file ok #608
# librosa read the file ok #609
# librosa read the file ok #610
# librosa read the file ok #611
# librosa read the file ok #612
# librosa read the file ok #613
# librosa read the file ok #614
# librosa read the file ok #615
# librosa read the file ok #616
# librosa read the file ok #617
# librosa read the file ok #618
# librosa read the file ok #619
# librosa read the file ok #620
# librosa read the file ok #621
# librosa read the file ok #622
# librosa read the file ok #623
# librosa read the file ok #624
# librosa read the file ok #625
# librosa read the file ok #626
# librosa read the file ok #627
# librosa read the file ok #628
# librosa read the file ok #629
# librosa read the file ok #630
# librosa read the file ok #631
# librosa read the file ok #632
# librosa read the file ok #633
# librosa read the file ok #634
# librosa read the file ok #635
# librosa read the file ok #636
# librosa read the file ok #637
# librosa read the file ok #638
# librosa read the file ok #639
# librosa read the file ok #640
# librosa read the file ok #641
# librosa read the file ok #642
# librosa read the file ok #643
# librosa read the file ok #644
# librosa read the file ok #645
# librosa read the file ok #646
# librosa read the file ok #647
# librosa read the file ok #648
# librosa read the file ok #649
# librosa read the file ok #650
# librosa read the file ok #651
# librosa read the file ok #652
# librosa read the file ok #653
# librosa read the file ok #654
# librosa read the file ok #655
# librosa read the file ok #656
# librosa read the file ok #657
# librosa read the file ok #658
# librosa read the file ok #659
# librosa read the file ok #660
# librosa read the file ok #661
# librosa read the file ok #662
# librosa read the file ok #663
# librosa read the file ok #664
# librosa read the file ok #665
# librosa read the file ok #666
# librosa read the file ok #667
# librosa read the file ok #668
# librosa read the file ok #669
# librosa read the file ok #670
# librosa read the file ok #671
# librosa read the file ok #672
# librosa read the file ok #673
# librosa read the file ok #674
# librosa read the file ok #675
# librosa read the file ok #676
# librosa read the file ok #677
# librosa read the file ok #678
# librosa read the file ok #679
# librosa read the file ok #680
# librosa read the file ok #681
# librosa read the file ok #682
# librosa read the file ok #683
# librosa read the file ok #684
# librosa read the file ok #685
# librosa read the file ok #686
# librosa read the file ok #687
# librosa read the file ok #688
# librosa read the file ok #689
# librosa read the file ok #690
# librosa read the file ok #691
# librosa read the file ok #692
# librosa read the file ok #693
# librosa read the file ok #694
# librosa read the file ok #695
# librosa read the file ok #696
# librosa read the file ok #697
# librosa read the file ok #698
# librosa read the file ok #699
# librosa read the file ok #700
# librosa read the file ok #701
# librosa read the file ok #702
# librosa read the file ok #703
# librosa read the file ok #704
# librosa read the file ok #705
# librosa read the file ok #706
# librosa read the file ok #707
# librosa read the file ok #708
# librosa read the file ok #709
# librosa read the file ok #710
# librosa read the file ok #711
# librosa read the file ok #712
# librosa read the file ok #713
# librosa read the file ok #714
# librosa read the file ok #715
# librosa read the file ok #716
# librosa read the file ok #717
# librosa read the file ok #718
# librosa read the file ok #719
# librosa read the file ok #720
# librosa read the file ok #721
# librosa read the file ok #722
# librosa read the file ok #723
# librosa read the file ok #724
# librosa read the file ok #725
# librosa read the file ok #726
# librosa read the file ok #727
# librosa read the file ok #728
# librosa read the file ok #729
# librosa read the file ok #730
# librosa read the file ok #731
# librosa read the file ok #732
# librosa read the file ok #733
# librosa read the file ok #734
# librosa read the file ok #735
# librosa read the file ok #736
# librosa read the file ok #737
# librosa read the file ok #738
# librosa read the file ok #739
# librosa read the file ok #740
# librosa read the file ok #741
# librosa read the file ok #742
# librosa read the file ok #743
# librosa read the file ok #744
# librosa read the file ok #745
# librosa read the file ok #746
# librosa read the file ok #747
# librosa read the file ok #748
# librosa read the file ok #749
# librosa read the file ok #750
# librosa read the file ok #751
# librosa read the file ok #752
# librosa read the file ok #753
# librosa read the file ok #754
# librosa read the file ok #755
# librosa read the file ok #756
# librosa read the file ok #757
# librosa read the file ok #758
# librosa read the file ok #759
# librosa read the file ok #760
# librosa read the file ok #761
# librosa read the file ok #762
# librosa read the file ok #763
# librosa read the file ok #764
# librosa read the file ok #765
# librosa read the file ok #766
# librosa read the file ok #767
# librosa read the file ok #768
# librosa read the file ok #769
# librosa read the file ok #770
# librosa read the file ok #771
# librosa read the file ok #772
# librosa read the file ok #773
# librosa read the file ok #774
# librosa read the file ok #775
# librosa read the file ok #776
# librosa read the file ok #777
# librosa read the file ok #778
# librosa read the file ok #779
# librosa read the file ok #780
# librosa read the file ok #781
# librosa read the file ok #782
# librosa read the file ok #783
# librosa read the file ok #784
# librosa read the file ok #785
# librosa read the file ok #786
# librosa read the file ok #787
# librosa read the file ok #788
# librosa read the file ok #789
# librosa read the file ok #790
# librosa read the file ok #791
# librosa read the file ok #792
# librosa read the file ok #793
# librosa read the file ok #794
# librosa read the file ok #795
# librosa read the file ok #796
# librosa read the file ok #797
# librosa read the file ok #798
# librosa read the file ok #799
# librosa read the file ok #800
# librosa read the file ok #801
# librosa read the file ok #802
# librosa read the file ok #803
# librosa read the file ok #804
# librosa read the file ok #805
# librosa read the file ok #806
# librosa read the file ok #807
# librosa read the file ok #808
# librosa read the file ok #809
# librosa read the file ok #810
# librosa read the file ok #811
# librosa read the file ok #812
# librosa read the file ok #813
# librosa read the file ok #814
# librosa read the file ok #815
# librosa read the file ok #816
# librosa read the file ok #817
# librosa read the file ok #818
# librosa read the file ok #819
# librosa read the file ok #820
# librosa read the file ok #821
# librosa read the file ok #822
# librosa read the file ok #823
# librosa read the file ok #824
# librosa read the file ok #825
# librosa read the file ok #826
# librosa read the file ok #827
# librosa read the file ok #828
# librosa read the file ok #829
# librosa read the file ok #830
# librosa read the file ok #831
# librosa read the file ok #832
# librosa read the file ok #833
# librosa read the file ok #834
# librosa read the file ok #835
# librosa read the file ok #836
# librosa read the file ok #837
# librosa read the file ok #838
# librosa read the file ok #839
# librosa read the file ok #840
# librosa read the file ok #841
# librosa read the file ok #842
# librosa read the file ok #843
# librosa read the file ok #844
# librosa read the file ok #845
# librosa read the file ok #846
# librosa read the file ok #847
# librosa read the file ok #848
# librosa read the file ok #849
# librosa read the file ok #850
# librosa read the file ok #851
# librosa read the file ok #852
# librosa read the file ok #853
# librosa read the file ok #854
# librosa read the file ok #855
# librosa read the file ok #856
# librosa read the file ok #857
# librosa read the file ok #858
# librosa read the file ok #859
# librosa read the file ok #860
# librosa read the file ok #861
# librosa read the file ok #862
# librosa read the file ok #863
# librosa read the file ok #864
# librosa read the file ok #865
# librosa read the file ok #866
# librosa read the file ok #867
# librosa read the file ok #868
# librosa read the file ok #869
# librosa read the file ok #870
# librosa read the file ok #871
# librosa read the file ok #872
# librosa read the file ok #873
# librosa read the file ok #874
# librosa read the file ok #875
# librosa read the file ok #876
# librosa read the file ok #877
# librosa read the file ok #878
# librosa read the file ok #879
# librosa read the file ok #880
# librosa read the file ok #881
# librosa read the file ok #882
# librosa read the file ok #883
# librosa read the file ok #884
# librosa read the file ok #885
# librosa read the file ok #886
# librosa read the file ok #887
# librosa read the file ok #888
# librosa read the file ok #889
# librosa read the file ok #890
# librosa read the file ok #891
# librosa read the file ok #892
# librosa read the file ok #893
# librosa read the file ok #894
# librosa read the file ok #895
# librosa read the file ok #896
# librosa read the file ok #897
# librosa read the file ok #898
# librosa read the file ok #899
# librosa read the file ok #900
# librosa read the file ok #901
# librosa read the file ok #902
# librosa read the file ok #903
# librosa read the file ok #904
# librosa read the file ok #905
# librosa read the file ok #906
# librosa read the file ok #907
# librosa read the file ok #908
# librosa read the file ok #909
# librosa read the file ok #910
# librosa read the file ok #911
# librosa read the file ok #912
# librosa read the file ok #913
# librosa read the file ok #914
# librosa read the file ok #915
# librosa read the file ok #916
# librosa read the file ok #917
# librosa read the file ok #918
# librosa read the file ok #919
# librosa read the file ok #920
# librosa read the file ok #921
# librosa read the file ok #922
# librosa read the file ok #923
# librosa read the file ok #924
# librosa read the file ok #925
# librosa read the file ok #926
# librosa read the file ok #927
# librosa read the file ok #928
# librosa read the file ok #929
# librosa read the file ok #930
# librosa read the file ok #931
# librosa read the file ok #932
# librosa read the file ok #933
# librosa read the file ok #934
# librosa read the file ok #935
# librosa read the file ok #936
# librosa read the file ok #937
# librosa read the file ok #938
# librosa read the file ok #939
# librosa read the file ok #940
# librosa read the file ok #941
# librosa read the file ok #942
# librosa read the file ok #943
# librosa read the file ok #944
# librosa read the file ok #945
# librosa read the file ok #946
# librosa read the file ok #947
# librosa read the file ok #948
# librosa read the file ok #949
# librosa read the file ok #950
# librosa read the file ok #951
# librosa read the file ok #952
# librosa read the file ok #953
# librosa read the file ok #954
# librosa read the file ok #955
# librosa read the file ok #956
# librosa read the file ok #957
# librosa read the file ok #958
# librosa read the file ok #959
# librosa read the file ok #960
# librosa read the file ok #961
# librosa read the file ok #962
# librosa read the file ok #963
# librosa read the file ok #964
# librosa read the file ok #965
# librosa read the file ok #966
# librosa read the file ok #967
# librosa read the file ok #968
# librosa read the file ok #969
# librosa read the file ok #970
# librosa read the file ok #971
# librosa read the file ok #972
# librosa read the file ok #973
# librosa read the file ok #974
# librosa read the file ok #975
# librosa read the file ok #976
# librosa read the file ok #977
# librosa read the file ok #978
# librosa read the file ok #979
# librosa read the file ok #980
# librosa read the file ok #981
# librosa read the file ok #982
# librosa read the file ok #983
# librosa read the file ok #984
# librosa read the file ok #985
# librosa read the file ok #986
# librosa read the file ok #987
# librosa read the file ok #988
# librosa read the file ok #989
# librosa read the file ok #990
# librosa read the file ok #991
# librosa read the file ok #992
# librosa read the file ok #993
# librosa read the file ok #994
# librosa read the file ok #995
# librosa read the file ok #996
# librosa read the file ok #997
# librosa read the file ok #998
# librosa read the file ok #999
# librosa read the file ok #1000
# librosa read the file ok #1001
# librosa read the file ok #1002
# librosa read the file ok #1003
# librosa read the file ok #1004
# librosa read the file ok #1005
# librosa read the file ok #1006
# librosa read the file ok #1007
# librosa read the file ok #1008
# librosa read the file ok #1009
# librosa read the file ok #1010
# librosa read the file ok #1011
# librosa read the file ok #1012
# librosa read the file ok #1013
# librosa read the file ok #1014
# librosa read the file ok #1015
# librosa read the file ok #1016
# librosa read the file ok #1017
# librosa read the file ok #1018
# librosa read the file ok #1019
# librosa read the file ok #1020
# librosa read the file ok #1021
# librosa read the file ok #1022
# librosa read the file ok #1023
# librosa read the file ok #1024
# librosa read the file ok #1025
# librosa read the file ok #1026
# librosa read the file ok #1027
# librosa read the file ok #1028
# librosa read the file ok #1029
# librosa read the file ok #1030
# librosa read the file ok #1031
# librosa read the file ok #1032
# librosa read the file ok #1033
# librosa read the file ok #1034
# librosa read the file ok #1035
# librosa read the file ok #1036
# librosa read the file ok #1037
# librosa read the file ok #1038
# librosa read the file ok #1039
# librosa read the file ok #1040
# librosa read the file ok #1041
# librosa read the file ok #1042
# librosa read the file ok #1043
# librosa read the file ok #1044
# librosa read the file ok #1045
# librosa read the file ok #1046
# librosa read the file ok #1047
# librosa read the file ok #1048
# librosa read the file ok #1049
# librosa read the file ok #1050
# librosa read the file ok #1051
# librosa read the file ok #1052
# librosa read the file ok #1053
# librosa read the file ok #1054
# librosa read the file ok #1055
# librosa read the file ok #1056
# librosa read the file ok #1057
# librosa read the file ok #1058
# librosa read the file ok #1059
# librosa read the file ok #1060
# librosa read the file ok #1061
# librosa read the file ok #1062
# librosa read the file ok #1063
# librosa read the file ok #1064
# librosa read the file ok #1065
# librosa read the file ok #1066
# librosa read the file ok #1067
# librosa read the file ok #1068
# librosa read the file ok #1069
# librosa read the file ok #1070
# librosa read the file ok #1071
# librosa read the file ok #1072
# librosa read the file ok #1073
# librosa read the file ok #1074
# librosa read the file ok #1075
# librosa read the file ok #1076
# librosa read the file ok #1077
# librosa read the file ok #1078
# librosa read the file ok #1079
# librosa read the file ok #1080
# librosa read the file ok #1081
# librosa read the file ok #1082
# librosa read the file ok #1083
# librosa read the file ok #1084
# librosa read the file ok #1085
# librosa read the file ok #1086
# librosa read the file ok #1087
# librosa read the file ok #1088
# librosa read the file ok #1089
# librosa read the file ok #1090
# librosa read the file ok #1091
# librosa read the file ok #1092
# librosa read the file ok #1093
# librosa read the file ok #1094
# librosa read the file ok #1095
# librosa read the file ok #1096
# librosa read the file ok #1097
# librosa read the file ok #1098
# librosa read the file ok #1099
# librosa read the file ok #1100
# librosa read the file ok #1101
# librosa read the file ok #1102
# librosa read the file ok #1103
# librosa read the file ok #1104
# librosa read the file ok #1105
# librosa read the file ok #1106
# librosa read the file ok #1107
# librosa read the file ok #1108
# librosa read the file ok #1109
# librosa read the file ok #1110
# librosa read the file ok #1111
# librosa read the file ok #1112
# librosa read the file ok #1113
# librosa read the file ok #1114
# librosa read the file ok #1115
# librosa read the file ok #1116
# librosa read the file ok #1117
# librosa read the file ok #1118
# librosa read the file ok #1119
# librosa read the file ok #1120
# librosa read the file ok #1121
# librosa read the file ok #1122
# librosa read the file ok #1123
# librosa read the file ok #1124
# librosa read the file ok #1125
# librosa read the file ok #1126
# librosa read the file ok #1127
# librosa read the file ok #1128
# librosa read the file ok #1129
# librosa read the file ok #1130
# librosa read the file ok #1131
# librosa read the file ok #1132
# librosa read the file ok #1133
# librosa read the file ok #1134
# librosa read the file ok #1135
# librosa read the file ok #1136
# librosa read the file ok #1137
# librosa read the file ok #1138
# librosa read the file ok #1139
# librosa read the file ok #1140
# librosa read the file ok #1141
# librosa read the file ok #1142
# librosa read the file ok #1143
# librosa read the file ok #1144
# librosa read the file ok #1145
# librosa read the file ok #1146
# librosa read the file ok #1147
# librosa read the file ok #1148
# librosa read the file ok #1149
# librosa read the file ok #1150
# librosa read the file ok #1151
# librosa read the file ok #1152
# librosa read the file ok #1153
# librosa read the file ok #1154
# librosa read the file ok #1155
# librosa read the file ok #1156
# librosa read the file ok #1157
# librosa read the file ok #1158
# librosa read the file ok #1159
# librosa read the file ok #1160
# librosa read the file ok #1161
# librosa read the file ok #1162
# librosa read the file ok #1163
# librosa read the file ok #1164
# librosa read the file ok #1165
# librosa read the file ok #1166
# librosa read the file ok #1167
# librosa read the file ok #1168
# librosa read the file ok #1169
# librosa read the file ok #1170
# librosa read the file ok #1171
# librosa read the file ok #1172
# librosa read the file ok #1173
# librosa read the file ok #1174
# librosa read the file ok #1175
# librosa read the file ok #1176
# librosa read the file ok #1177
# librosa read the file ok #1178
# librosa read the file ok #1179
# librosa read the file ok #1180
# librosa read the file ok #1181
# librosa read the file ok #1182
# librosa read the file ok #1183
# librosa read the file ok #1184
# librosa read the file ok #1185
# librosa read the file ok #1186
# librosa read the file ok #1187
# librosa read the file ok #1188
# librosa read the file ok #1189
# librosa read the file ok #1190
# librosa read the file ok #1191
# librosa read the file ok #1192
# librosa read the file ok #1193
# librosa read the file ok #1194
# librosa read the file ok #1195
# librosa read the file ok #1196
# librosa read the file ok #1197
# librosa read the file ok #1198
# librosa read the file ok #1199
# librosa read the file ok #1200
# librosa read the file ok #1201
# librosa read the file ok #1202
# librosa read the file ok #1203
# librosa read the file ok #1204
# librosa read the file ok #1205
# librosa read the file ok #1206
# librosa read the file ok #1207
# librosa read the file ok #1208
# librosa read the file ok #1209
# librosa read the file ok #1210
# librosa read the file ok #1211
# librosa read the file ok #1212
# librosa read the file ok #1213
# librosa read the file ok #1214
# librosa read the file ok #1215
# librosa read the file ok #1216
# librosa read the file ok #1217
# librosa read the file ok #1218
# librosa read the file ok #1219
# librosa read the file ok #1220
# librosa read the file ok #1221
# librosa read the file ok #1222
# librosa read the file ok #1223
# librosa read the file ok #1224
# librosa read the file ok #1225
# librosa read the file ok #1226
# librosa read the file ok #1227
# librosa read the file ok #1228
# librosa read the file ok #1229
# librosa read the file ok #1230
# librosa read the file ok #1231
# librosa read the file ok #1232
# librosa read the file ok #1233
# librosa read the file ok #1234
# librosa read the file ok #1235
# librosa read the file ok #1236
# librosa read the file ok #1237
# librosa read the file ok #1238
# librosa read the file ok #1239
# librosa read the file ok #1240
# librosa read the file ok #1241
# librosa read the file ok #1242
# librosa read the file ok #1243
# librosa read the file ok #1244
# librosa read the file ok #1245
# librosa read the file ok #1246
# librosa read the file ok #1247
# librosa read the file ok #1248
# librosa read the file ok #1249
# librosa read the file ok #1250
# librosa read the file ok #1251
# librosa read the file ok #1252
# librosa read the file ok #1253
# librosa read the file ok #1254
# librosa read the file ok #1255
# librosa read the file ok #1256
# librosa read the file ok #1257
# librosa read the file ok #1258
# librosa read the file ok #1259
# librosa read the file ok #1260
# librosa read the file ok #1261
# librosa read the file ok #1262
# librosa read the file ok #1263
# librosa read the file ok #1264
# librosa read the file ok #1265
# librosa read the file ok #1266
# librosa read the file ok #1267
# librosa read the file ok #1268
# librosa read the file ok #1269
# librosa read the file ok #1270
# librosa read the file ok #1271
# librosa read the file ok #1272
# librosa read the file ok #1273
# librosa read the file ok #1274
# librosa read the file ok #1275
# librosa read the file ok #1276
# librosa read the file ok #1277
# librosa read the file ok #1278
# librosa read the file ok #1279
# librosa read the file ok #1280
# librosa read the file ok #1281
# librosa read the file ok #1282
# librosa read the file ok #1283
# librosa read the file ok #1284
# librosa read the file ok #1285
# librosa read the file ok #1286
# librosa read the file ok #1287
# librosa read the file ok #1288
# librosa read the file ok #1289
# librosa read the file ok #1290
# librosa read the file ok #1291
# librosa read the file ok #1292
# librosa read the file ok #1293
# librosa read the file ok #1294
# librosa read the file ok #1295
# librosa read the file ok #1296
# librosa read the file ok #1297
# librosa read the file ok #1298
# librosa read the file ok #1299
# librosa read the file ok #1300
# librosa read the file ok #1301
# librosa read the file ok #1302
# librosa read the file ok #1303
# librosa read the file ok #1304
# librosa read the file ok #1305
# librosa read the file ok #1306
# librosa read the file ok #1307
# librosa read the file ok #1308
# librosa read the file ok #1309
# librosa read the file ok #1310
# librosa read the file ok #1311
# librosa read the file ok #1312
# librosa read the file ok #1313
# librosa read the file ok #1314
# librosa read the file ok #1315
# librosa read the file ok #1316
# librosa read the file ok #1317
# librosa read the file ok #1318
# librosa read the file ok #1319
# librosa read the file ok #1320
# librosa read the file ok #1321
# librosa read the file ok #1322
# librosa read the file ok #1323
# librosa read the file ok #1324
# librosa read the file ok #1325
# librosa read the file ok #1326
# librosa read the file ok #1327
# librosa read the file ok #1328
# librosa read the file ok #1329
# librosa read the file ok #1330
# librosa read the file ok #1331
# librosa read the file ok #1332
# librosa read the file ok #1333
# librosa read the file ok #1334
# librosa read the file ok #1335
# librosa read the file ok #1336
# librosa read the file ok #1337
# librosa read the file ok #1338
# librosa read the file ok #1339
# librosa read the file ok #1340
# librosa read the file ok #1341
# librosa read the file ok #1342
# librosa read the file ok #1343
# librosa read the file ok #1344
# librosa read the file ok #1345
# librosa read the file ok #1346
# librosa read the file ok #1347
# librosa read the file ok #1348
# librosa read the file ok #1349
# librosa read the file ok #1350
# librosa read the file ok #1351
# librosa read the file ok #1352
# librosa read the file ok #1353
# librosa read the file ok #1354
# librosa read the file ok #1355
# librosa read the file ok #1356
# librosa read the file ok #1357
# librosa read the file ok #1358
# librosa read the file ok #1359
# librosa read the file ok #1360
# librosa read the file ok #1361
# librosa read the file ok #1362
# librosa read the file ok #1363
# librosa read the file ok #1364
# librosa read the file ok #1365
# librosa read the file ok #1366
# librosa read the file ok #1367
# librosa read the file ok #1368
# librosa read the file ok #1369
# librosa read the file ok #1370
# librosa read the file ok #1371
# librosa read the file ok #1372
# librosa read the file ok #1373
# librosa read the file ok #1374
# librosa read the file ok #1375
# librosa read the file ok #1376
# librosa read the file ok #1377
# librosa read the file ok #1378
# librosa read the file ok #1379
# librosa read the file ok #1380
# librosa read the file ok #1381
# librosa read the file ok #1382
# librosa read the file ok #1383
# librosa read the file ok #1384
# librosa read the file ok #1385
# librosa read the file ok #1386
# librosa read the file ok #1387
# librosa read the file ok #1388
# librosa read the file ok #1389
# librosa read the file ok #1390
# librosa read the file ok #1391
# librosa read the file ok #1392
# librosa read the file ok #1393
# librosa read the file ok #1394
# librosa read the file ok #1395
# librosa read the file ok #1396
# librosa read the file ok #1397
# librosa read the file ok #1398
# librosa read the file ok #1399
# librosa read the file ok #1400
# librosa read the file ok #1401
# librosa read the file ok #1402
# librosa read the file ok #1403
# librosa read the file ok #1404
# librosa read the file ok #1405
# librosa read the file ok #1406
# librosa read the file ok #1407
# librosa read the file ok #1408
# librosa read the file ok #1409
# librosa read the file ok #1410
# librosa read the file ok #1411
# librosa read the file ok #1412
# librosa read the file ok #1413
# librosa read the file ok #1414
# librosa read the file ok #1415
# librosa read the file ok #1416
# librosa read the file ok #1417
# librosa read the file ok #1418
# librosa read the file ok #1419
# librosa read the file ok #1420
# librosa read the file ok #1421
# librosa read the file ok #1422
# librosa read the file ok #1423
# librosa read the file ok #1424
# librosa read the file ok #1425
# librosa read the file ok #1426
# librosa read the file ok #1427
# librosa read the file ok #1428
# librosa read the file ok #1429
# librosa read the file ok #1430
# librosa read the file ok #1431
# librosa read the file ok #1432
# librosa read the file ok #1433
# librosa read the file ok #1434
# librosa read the file ok #1435
# librosa read the file ok #1436
# librosa read the file ok #1437
# librosa read the file ok #1438
# librosa read the file ok #1439
# librosa read the file ok #1440
# librosa read the file ok #1441
# librosa read the file ok #1442
# librosa read the file ok #1443
# librosa read the file ok #1444
# librosa read the file ok #1445
# librosa read the file ok #1446
# librosa read the file ok #1447
# librosa read the file ok #1448
# librosa read the file ok #1449
# librosa read the file ok #1450
# librosa read the file ok #1451
# librosa read the file ok #1452
# librosa read the file ok #1453
# librosa read the file ok #1454
# librosa read the file ok #1455
# librosa read the file ok #1456
# librosa read the file ok #1457
# librosa read the file ok #1458
# librosa read the file ok #1459
# librosa read the file ok #1460
# librosa read the file ok #1461
# librosa read the file ok #1462
# librosa read the file ok #1463
# librosa read the file ok #1464
# librosa read the file ok #1465
# librosa read the file ok #1466
# librosa read the file ok #1467
# librosa read the file ok #1468
# librosa read the file ok #1469
# librosa read the file ok #1470
# librosa read the file ok #1471
# librosa read the file ok #1472
# librosa read the file ok #1473
# librosa read the file ok #1474
# librosa read the file ok #1475
# librosa read the file ok #1476
# librosa read the file ok #1477
# librosa read the file ok #1478
# librosa read the file ok #1479
# librosa read the file ok #1480
# librosa read the file ok #1481
# librosa read the file ok #1482
# librosa read the file ok #1483
# librosa read the file ok #1484
# librosa read the file ok #1485
# librosa read the file ok #1486
# librosa read the file ok #1487
# librosa read the file ok #1488
# librosa read the file ok #1489
# librosa read the file ok #1490
# librosa read the file ok #1491
# librosa read the file ok #1492
# librosa read the file ok #1493
# librosa read the file ok #1494
# librosa read the file ok #1495
# librosa read the file ok #1496
# librosa read the file ok #1497
# librosa read the file ok #1498
# librosa read the file ok #1499
# librosa read the file ok #1500
# librosa read the file ok #1501
# librosa read the file ok #1502
# librosa read the file ok #1503
# librosa read the file ok #1504
# librosa read the file ok #1505
# librosa read the file ok #1506
# librosa read the file ok #1507
# librosa read the file ok #1508
# librosa read the file ok #1509
# librosa read the file ok #1510
# librosa read the file ok #1511
# librosa read the file ok #1512
# librosa read the file ok #1513
# librosa read the file ok #1514
# librosa read the file ok #1515
# librosa read the file ok #1516
# librosa read the file ok #1517
# librosa read the file ok #1518
# librosa read the file ok #1519
# librosa read the file ok #1520
# librosa read the file ok #1521
# librosa read the file ok #1522
# librosa read the file ok #1523
# librosa read the file ok #1524
# librosa read the file ok #1525
# librosa read the file ok #1526
# librosa read the file ok #1527
# librosa read the file ok #1528
# librosa read the file ok #1529
# librosa read the file ok #1530
# librosa read the file ok #1531
# librosa read the file ok #1532
# librosa read the file ok #1533
# librosa read the file ok #1534
# librosa read the file ok #1535
# librosa read the file ok #1536
# librosa read the file ok #1537
# librosa read the file ok #1538
# librosa read the file ok #1539
# librosa read the file ok #1540
# librosa read the file ok #1541
# librosa read the file ok #1542
# librosa read the file ok #1543
# librosa read the file ok #1544
# librosa read the file ok #1545
# librosa read the file ok #1546
# librosa read the file ok #1547
# librosa read the file ok #1548
# librosa read the file ok #1549
# librosa read the file ok #1550
# librosa read the file ok #1551
# librosa read the file ok #1552
# librosa read the file ok #1553
# librosa read the file ok #1554
# librosa read the file ok #1555
# librosa read the file ok #1556
# librosa read the file ok #1557
# librosa read the file ok #1558
# librosa read the file ok #1559
# librosa read the file ok #1560
# librosa read the file ok #1561
# librosa read the file ok #1562
# librosa read the file ok #1563
# librosa read the file ok #1564
# librosa read the file ok #1565
# librosa read the file ok #1566
# librosa read the file ok #1567
# librosa read the file ok #1568
# librosa read the file ok #1569
# librosa read the file ok #1570
# librosa read the file ok #1571
# librosa read the file ok #1572
# librosa read the file ok #1573
# librosa read the file ok #1574
# librosa read the file ok #1575
# librosa read the file ok #1576
# librosa read the file ok #1577
# librosa read the file ok #1578
# librosa read the file ok #1579
# librosa read the file ok #1580
# librosa read the file ok #1581
# librosa read the file ok #1582
# librosa read the file ok #1583
# librosa read the file ok #1584
# librosa read the file ok #1585
# librosa read the file ok #1586
# librosa read the file ok #1587
# librosa read the file ok #1588
# librosa read the file ok #1589
# librosa read the file ok #1590
# librosa read the file ok #1591
# librosa read the file ok #1592
# librosa read the file ok #1593
# librosa read the file ok #1594
# librosa read the file ok #1595
# librosa read the file ok #1596
# librosa read the file ok #1597
# librosa read the file ok #1598
# librosa read the file ok #1599
# librosa read the file ok #1600
# librosa read the file ok #1601
# librosa read the file ok #1602
# librosa read the file ok #1603
# librosa read the file ok #1604
# librosa read the file ok #1605
# librosa read the file ok #1606
# librosa read the file ok #1607
# librosa read the file ok #1608
# librosa read the file ok #1609
# librosa read the file ok #1610
# librosa read the file ok #1611
# librosa read the file ok #1612
# librosa read the file ok #1613
# librosa read the file ok #1614
# librosa read the file ok #1615
# librosa read the file ok #1616
# librosa read the file ok #1617
# librosa read the file ok #1618
# librosa read the file ok #1619
# librosa read the file ok #1620
# librosa read the file ok #1621
# librosa read the file ok #1622
# librosa read the file ok #1623
# librosa read the file ok #1624
# librosa read the file ok #1625
# librosa read the file ok #1626
# librosa read the file ok #1627
# librosa read the file ok #1628
# librosa read the file ok #1629
# librosa read the file ok #1630
# librosa read the file ok #1631
# librosa read the file ok #1632
# librosa read the file ok #1633
# librosa read the file ok #1634
# librosa read the file ok #1635
# librosa read the file ok #1636
# librosa read the file ok #1637
# librosa read the file ok #1638
# librosa read the file ok #1639
# librosa read the file ok #1640
# librosa read the file ok #1641
# librosa read the file ok #1642
# librosa read the file ok #1643
# librosa read the file ok #1644
# librosa read the file ok #1645
# librosa read the file ok #1646
# librosa read the file ok #1647
# librosa read the file ok #1648
# librosa read the file ok #1649
# librosa read the file ok #1650
# librosa read the file ok #1651
# librosa read the file ok #1652
# librosa read the file ok #1653
# librosa read the file ok #1654
# librosa read the file ok #1655
# librosa read the file ok #1656
# librosa read the file ok #1657
# librosa read the file ok #1658
# librosa read the file ok #1659
# librosa read the file ok #1660
# librosa read the file ok #1661
# librosa read the file ok #1662
# librosa read the file ok #1663
# librosa read the file ok #1664
# librosa read the file ok #1665
# librosa read the file ok #1666
# librosa read the file ok #1667
# librosa read the file ok #1668
# librosa read the file ok #1669
# librosa read the file ok #1670
# librosa read the file ok #1671
# librosa read the file ok #1672
# librosa read the file ok #1673
# librosa read the file ok #1674
# librosa read the file ok #1675
# librosa read the file ok #1676
# librosa read the file ok #1677
# librosa read the file ok #1678
# librosa read the file ok #1679
# librosa read the file ok #1680
# librosa read the file ok #1681
# librosa read the file ok #1682
# librosa read the file ok #1683
# librosa read the file ok #1684
# librosa read the file ok #1685
# librosa read the file ok #1686
# librosa read the file ok #1687
# librosa read the file ok #1688
# librosa read the file ok #1689
# librosa read the file ok #1690
# librosa read the file ok #1691
# librosa read the file ok #1692
# librosa read the file ok #1693
# librosa read the file ok #1694
# librosa read the file ok #1695
# librosa read the file ok #1696
# librosa read the file ok #1697
# librosa read the file ok #1698
# librosa read the file ok #1699
# librosa read the file ok #1700
# librosa read the file ok #1701
# librosa read the file ok #1702
# librosa read the file ok #1703
# librosa read the file ok #1704
# librosa read the file ok #1705
# librosa read the file ok #1706
# librosa read the file ok #1707
# librosa read the file ok #1708
# librosa read the file ok #1709
# librosa read the file ok #1710
# librosa read the file ok #1711
# librosa read the file ok #1712
# librosa read the file ok #1713
# librosa read the file ok #1714
# librosa read the file ok #1715
# librosa read the file ok #1716
# librosa read the file ok #1717
# librosa read the file ok #1718
# librosa read the file ok #1719
# librosa read the file ok #1720
# librosa read the file ok #1721
# librosa read the file ok #1722
# librosa read the file ok #1723
# librosa read the file ok #1724
# librosa read the file ok #1725
# librosa read the file ok #1726
# librosa read the file ok #1727
# librosa read the file ok #1728
# librosa read the file ok #1729
# librosa read the file ok #1730
# librosa read the file ok #1731
# librosa read the file ok #1732
# librosa read the file ok #1733
# librosa read the file ok #1734
# librosa read the file ok #1735
# librosa read the file ok #1736
# librosa read the file ok #1737
# librosa read the file ok #1738
# librosa read the file ok #1739
# librosa read the file ok #1740
# librosa read the file ok #1741
# librosa read the file ok #1742
# librosa read the file ok #1743
# librosa read the file ok #1744
# librosa read the file ok #1745
# librosa read the file ok #1746
# librosa read the file ok #1747
# librosa read the file ok #1748
# librosa read the file ok #1749
# librosa read the file ok #1750
# librosa read the file ok #1751
# librosa read the file ok #1752
# librosa read the file ok #1753
# librosa read the file ok #1754
# librosa read the file ok #1755
# librosa read the file ok #1756
# librosa read the file ok #1757
# librosa read the file ok #1758
# librosa read the file ok #1759
# librosa read the file ok #1760
# librosa read the file ok #1761
# librosa read the file ok #1762
# librosa read the file ok #1763
# librosa read the file ok #1764
# librosa read the file ok #1765
# librosa read the file ok #1766
# librosa read the file ok #1767
# librosa read the file ok #1768
# librosa read the file ok #1769
# librosa read the file ok #1770
# librosa read the file ok #1771
# librosa read the file ok #1772
# librosa read the file ok #1773
# librosa read the file ok #1774
# librosa read the file ok #1775
# librosa read the file ok #1776
# librosa read the file ok #1777
# librosa read the file ok #1778
# librosa read the file ok #1779
# librosa read the file ok #1780
# librosa read the file ok #1781
# librosa read the file ok #1782
# librosa read the file ok #1783
# librosa read the file ok #1784
# librosa read the file ok #1785
# librosa read the file ok #1786
# librosa read the file ok #1787
# librosa read the file ok #1788
# librosa read the file ok #1789
# librosa read the file ok #1790
# librosa read the file ok #1791
# librosa read the file ok #1792
# librosa read the file ok #1793
# librosa read the file ok #1794
# librosa read the file ok #1795
# librosa read the file ok #1796
# librosa read the file ok #1797
# librosa read the file ok #1798
# librosa read the file ok #1799
# librosa read the file ok #1800
# Urban sound unrecognized by Librosa: [[ 0.00289917  0.04449463]
#  [ 0.00192261  0.0375061 ]
#  [ 0.00109863  0.02972412]
#  ...
#  [-0.0045166   0.        ]
#  [-0.0045166   0.00057983]
#  [-0.00430298  0.0010376 ]]
# librosa read the file ok #1801
# librosa read the file ok #1802
# librosa read the file ok #1803
# librosa read the file ok #1804
# librosa read the file ok #1805
# librosa read the file ok #1806
# librosa read the file ok #1807
# librosa read the file ok #1808
# librosa read the file ok #1809
# librosa read the file ok #1810
# librosa read the file ok #1811
# librosa read the file ok #1812
# librosa read the file ok #1813
# librosa read the file ok #1814
# librosa read the file ok #1815
# librosa read the file ok #1816
# librosa read the file ok #1817
# librosa read the file ok #1818
# librosa read the file ok #1819
# librosa read the file ok #1820
# librosa read the file ok #1821
# librosa read the file ok #1822
# librosa read the file ok #1823
# librosa read the file ok #1824
# librosa read the file ok #1825
# librosa read the file ok #1826
# librosa read the file ok #1827
# librosa read the file ok #1828
# librosa read the file ok #1829
# librosa read the file ok #1830
# librosa read the file ok #1831
# librosa read the file ok #1832
# librosa read the file ok #1833
# librosa read the file ok #1834
# librosa read the file ok #1835
# librosa read the file ok #1836
# librosa read the file ok #1837
# librosa read the file ok #1838
# librosa read the file ok #1839
# librosa read the file ok #1840
# librosa read the file ok #1841
# librosa read the file ok #1842
# librosa read the file ok #1843
# librosa read the file ok #1844
# librosa read the file ok #1845
# librosa read the file ok #1846
# librosa read the file ok #1847

# %%
'''
glassbreak_aggregator_inverted = dict([[v, k] for k, v in glassbreak_aggregator.items()])
for sl in sorted(glassbreak_aggregator.values(), reverse=True):
    print("Max value for slice #" + str(glassbreak_aggregator_inverted[sl]) + " is " + str(sl))
'''
# Out:
# '\nglassbreak_aggregator_inverted = dict([[v, k] for k, v in glassbreak_aggregator.items()])\nfor sl in sorted(glassbreak_aggregator.values(), reverse=True):\n    print("Max value for slice #" + str(glassbreak_aggregator_inverted[sl]) + " is " + str(sl))\n'

# %%
print(len(samples))
i=744
samp=samples[i]
sr=sample_rates[i]
print(np.max(abs(samp)))
print(labels[i])
ipd.Audio(samp, rate=sr)
# Out:
# 2448
# 0.6194935
# 1
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
'''
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)
'''
# Out:
# "\ndef log_specgram(audio, sample_rate, window_size=20,\n                 step_size=10, eps=1e-10):\n    nperseg = int(round(window_size * sample_rate / 1e3))\n    noverlap = int(round(step_size * sample_rate / 1e3))\n    freqs, times, spec = signal.spectrogram(audio,\n                                    fs=sample_rate,\n                                    window='hann',\n                                    nperseg=nperseg,\n                                    noverlap=noverlap,\n                                    detrend=False)\n    return freqs, times, np.log(spec.T.astype(np.float32) + eps)\n"

# %%
'''
i=15
samp=samples[i]
sr=sample_rates[i]

freqs, times, spectrogram = log_specgram(samp, sr)

fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave of ' + file)
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, 1,samp.size), samp)

ax2 = fig.add_subplot(212)
ax2.imshow(spectrogram.T, aspect='auto', origin='lower', 
           extent=[times.min(), times.max(), freqs.min(), freqs.max()])
ax2.set_yticks(freqs[::16])
ax2.set_xticks(times[::16])
ax2.set_title('Spectrogram of ' + file)
ax2.set_ylabel('Freqs in Hz')
ax2.set_xlabel('Seconds')
'''
# Out:
# "\ni=15\nsamp=samples[i]\nsr=sample_rates[i]\n\nfreqs, times, spectrogram = log_specgram(samp, sr)\n\nfig = plt.figure(figsize=(14, 8))\nax1 = fig.add_subplot(211)\nax1.set_title('Raw wave of ' + file)\nax1.set_ylabel('Amplitude')\nax1.plot(np.linspace(0, 1,samp.size), samp)\n\nax2 = fig.add_subplot(212)\nax2.imshow(spectrogram.T, aspect='auto', origin='lower', \n           extent=[times.min(), times.max(), freqs.min(), freqs.max()])\nax2.set_yticks(freqs[::16])\nax2.set_xticks(times[::16])\nax2.set_title('Spectrogram of ' + file)\nax2.set_ylabel('Freqs in Hz')\nax2.set_xlabel('Seconds')\n"

# %%
kf = KFold(n_splits=3, shuffle=True)
samples = np.array(samples)
labels = np.array(labels)
for train_index, test_index in kf.split(samples):
    print("TRAIN:", train_index, "TEST:", test_index)
    train_wav, test_wav = samples[train_index], samples[test_index]
    train_label, test_label = labels[train_index], labels[test_index]
# Out:
#  1966 1971 1973 1974 1975 1977 1979 1980 1981 1986 1994 2005 2010 2011
#  2015 2017 2020 2029 2034 2039 2041 2045 2049 2050 2052 2056 2063 2069
#  2070 2071 2072 2076 2080 2082 2085 2092 2093 2094 2102 2108 2110 2112
#  2113 2115 2121 2122 2123 2127 2128 2129 2133 2135 2136 2138 2142 2146
#  2150 2151 2152 2155 2156 2158 2160 2164 2166 2170 2171 2172 2173 2174
#  2175 2177 2180 2181 2185 2186 2187 2189 2190 2192 2195 2197 2199 2200
#  2202 2205 2207 2209 2212 2213 2221 2227 2234 2235 2239 2243 2246 2248
#  2257 2258 2267 2279 2280 2281 2286 2288 2289 2292 2299 2307 2308 2310
#  2311 2312 2313 2315 2320 2324 2325 2327 2330 2331 2334 2336 2340 2342
#  2343 2344 2346 2348 2353 2354 2361 2362 2364 2366 2369 2376 2378 2384
#  2386 2391 2394 2397 2402 2403 2407 2408 2409 2419 2427 2429 2431 2436
#  2441 2442 2444 2445]

# %%
# Parameters
lr = 0.001
generations = 20000
num_gens_to_wait = 250
batch_size = 256
drop_out_rate = 0.2
input_shape = (44100,1)

# %%
#For Conv1D add Channel
train_wav = np.array(train_wav)
test_wav = np.array(test_wav)
train_wav = train_wav.reshape(-1,44100,1)
test_wav = test_wav.reshape(-1,44100,1)
train_label = keras.utils.to_categorical(train_label, 3)
test_label = keras.utils.to_categorical(test_label, 3)

# %%
print(train_wav.shape)
# Out:
# (1632, 44100, 1)

# %%
input_tensor = Input(shape=input_shape)

x = layers.Conv1D(8, 11, padding='valid', activation='relu', strides=1)(input_tensor)
x = layers.MaxPooling1D(2)(x)
x = layers.Conv1D(16, 7, padding='valid', activation='relu', strides=1)(x)
x = layers.MaxPooling1D(4)(x)
x = layers.Conv1D(32, 5, padding='valid', activation='relu', strides=1)(x)
x = layers.MaxPooling1D(4)(x)
x = layers.Conv1D(64, 5, padding='valid', activation='relu', strides=1)(x)
x = layers.MaxPooling1D(6)(x)
x = layers.Conv1D(128, 3, padding='valid', activation='relu', strides=1)(x)
x = layers.MaxPooling1D(6)(x)
x = layers.Conv1D(256, 3, padding='valid', activation='relu', strides=1)(x)
x = layers.MaxPooling1D(6)(x)
x = layers.Flatten()(x)
x = layers.Dense(100, activation='relu')(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.Dense(50, activation='relu')(x)
x = layers.Dropout(drop_out_rate)(x)
x = layers.Dense(20, activation='relu')(x)
output_tensor = layers.Dense(3, activation='softmax')(x)

model = tf.keras.Model(input_tensor, output_tensor)

model.compile(loss=keras.losses.categorical_crossentropy,
             optimizer=keras.optimizers.Adam(lr = lr),
             metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/keras/layers/core.py:143: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 44100, 1)          0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 44090, 8)          96
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 22045, 8)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 22039, 16)         912
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 5509, 16)          0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 5505, 32)          2592
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 1376, 32)          0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 1372, 64)          10304
# _________________________________________________________________
# max_pooling1d_3 (MaxPooling1 (None, 228, 64)           0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 226, 128)          24704
# _________________________________________________________________
# max_pooling1d_4 (MaxPooling1 (None, 37, 128)           0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 35, 256)           98560
# _________________________________________________________________
# max_pooling1d_5 (MaxPooling1 (None, 5, 256)            0
# _________________________________________________________________
# flatten (Flatten)            (None, 1280)              0
# _________________________________________________________________
# dense (Dense)                (None, 100)               128100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 50)                5050
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 50)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_3 (Dense)              (None, 3)                 63
# =================================================================
# Total params: 271,401
# Trainable params: 271,401
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(train_wav, train_label, 
          validation_data=[test_wav, test_label],
          batch_size=batch_size, 
          epochs=50,
          verbose=1)
# Out:
# Train on 579 samples, validate on 289 samples
# WARNING:tensorflow:From /usr/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/50
#
50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3349 - acc: 0.9016 - val_loss: 0.3974 - val_acc: 0.8858
# Epoch 35/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3373 - acc: 0.9085 - val_loss: 0.4138 - val_acc: 0.8720
# Epoch 36/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3207 - acc: 0.9016 - val_loss: 0.4431 - val_acc: 0.8720
# Epoch 37/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3134 - acc: 0.9171 - val_loss: 0.4315 - val_acc: 0.8824
# Epoch 38/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2929 - acc: 0.9188 - val_loss: 0.4306 - val_acc: 0.8962
# Epoch 39/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3066 - acc: 0.9119 - val_loss: 0.4388 - val_acc: 0.8824
# Epoch 40/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2942 - acc: 0.9136 - val_loss: 0.4257 - val_acc: 0.8789
# Epoch 41/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2951 - acc: 0.9171 - val_loss: 0.4688 - val_acc: 0.8858
# Epoch 42/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2960 - acc: 0.9102 - val_loss: 0.4155 - val_acc: 0.8927
# Epoch 43/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.3048 - acc: 0.9136 - val_loss: 0.4829 - val_acc: 0.8893
# Epoch 44/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2890 - acc: 0.9171 - val_loss: 0.4200 - val_acc: 0.8858
# Epoch 45/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2864 - acc: 0.9240 - val_loss: 0.4052 - val_acc: 0.9031
# Epoch 46/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2730 - acc: 0.9188 - val_loss: 0.4399 - val_acc: 0.8962
# Epoch 47/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2601 - acc: 0.9292 - val_loss: 0.4101 - val_acc: 0.8720
# Epoch 48/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2861 - acc: 0.9257 - val_loss: 0.4456 - val_acc: 0.9031
# Epoch 49/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2649 - acc: 0.9188 - val_loss: 0.3951 - val_acc: 0.9135
# Epoch 50/50
# 579/579 [==============================] - 2s 3ms/sample - loss: 0.2674 - acc: 0.9188 - val_loss: 0.4051 - val_acc: 0.8824

# %%
Y_test_pred = model.predict(test_wav)
y_predicted_classes_test = Y_test_pred.argmax(axis=-1)
y_actual_classes_test= test_label.argmax(axis=-1)
wrong_examples = np.nonzero(y_predicted_classes_test != y_actual_classes_test)
# Out:
# (289,)

# %%
print(wrong_examples)
# Out:
# (array([  1,   5,  19,  41,  50,  52,  55,  57,  58,  64,  65,  67,  75,
#         81, 112, 115, 116, 120, 121, 135, 138, 158, 193, 209, 224, 225,
#        232, 235, 249, 256, 270, 284, 285, 287]),)

# %%
i=1
samp=np.reshape(test_wav[i],44100,)
sr=sample_rates[i]
print(y_test[i],Y_test_pred[i])
ipd.Audio(samp, rate=sr)
# Out:
# 2 [0.554347   0.3448235  0.10082955]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
i=5
samp=np.reshape(test_wav[i],44100,)
sr=sample_rates[i]
print(y_test[i],Y_test_pred[i])
ipd.Audio(samp, rate=sr)

# %%
i=19
samp=np.reshape(test_wav[i],44100,)
sr=sample_rates[i]
print(y_test[i],Y_test_pred[i])
ipd.Audio(samp, rate=sr)
# Out:
# 0 [0.9313842  0.06127589 0.00733979]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
i=41
samp=np.reshape(test_wav[i],44100,)
sr=sample_rates[i]
print(y_test[i],Y_test_pred[i])
ipd.Audio(samp, rate=sr)
# Out:
# 2 [5.9865852e-06 5.2870007e-07 9.9999344e-01]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
i=50
samp=np.reshape(test_wav[i],44100,)
sr=sample_rates[i]
print(y_test[i],Y_test_pred[i])
ipd.Audio(samp, rate=sr)
# Out:
# 2 [0.7274393  0.1795184  0.09304236]
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
